# %%
import matplotlib.pyplot as plt

# First dataset
pressure_1 = [0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0, 5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2]
loading_absolute_average_ch4 = [0.02107197241556, 0.09000232285968, 0.15578324137112, 0.22562270618756, 
                                 0.28942305410216, 0.3594248607708, 0.42329014542628, 0.49485043387604, 
                                 0.55355324763156, 0.62465897889516, 0.68855673192108, 0.77719538322228, 
                                 0.81943673316472, 0.89294512384088, 0.94408280728388, 1.048728365212, 
                                 1.1086000403034, 1.1198990332165]
loading_absolute_dev_1 = [0.0040521775042647, 0.0031984229048746, 0.014401616462403, 0.014429113324664, 
                          0.018773794660594, 0.0077190093813699, 0.013727018808283, 0.034998674445626, 
                          0.026617252448644, 0.026968221458062, 0.015140986713557, 0.037225577877315, 
                          0.016939156807388, 0.04289444085643, 0.039768969379805, 0.072852830282851, 
                          0.052719436084455, 0.027677529017746]

# Second dataset
pressure_2 = [0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0, 5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2]
loading_absolute_average_co2 = [0.09948308702816, 0.40416627523712, 0.71871984805984, 1.0512284297359, 
                                 1.3815616305924, 1.7537465609462, 2.2081738736244, 2.4587647566803, 
                                 2.8650090076256, 3.2489474880786, 3.6257104586644, 4.1413731179924, 
                                 4.4101787568652, 5.0669489541255, 5.6187489097533, 5.9866155468385, 
                                 6.6655291727389, 6.9483936160122]
loading_absolute_dev_2 = [0.0084452721838453, 0.016632681365131, 0.024206166406264, 0.019770651687065, 
                          0.071575313074542, 0.14468911361547, 0.1363775144108, 0.040611481351374, 
                          0.090167418110864, 0.17745549176295, 0.17507352395585, 0.24369153981299, 
                          0.64594407634046, 0.47156230509188, 0.48440056204987, 0.64660919423693, 
                          0.59399836541979, 0.28155248416957]

# Create plot
plt.figure(figsize=(8, 6))

# Plot first dataset with error bars
plt.errorbar(pressure_1, loading_absolute_average_ch4, yerr=loading_absolute_dev_1, 
             fmt='o', color='b', label='Methane pure isotherm and absolute deviation', capsize=5)

# Plot second dataset with error bars
plt.errorbar(pressure_2, loading_absolute_average_co2, yerr=loading_absolute_dev_2, 
             fmt='o', color='r', label='Carbon Dioxide pure isotherm and absolute deviation', capsize=5)
             

# Adding title and labels
plt.title('Pressure vs. Loading Absolute Average (with Error Bars)')
plt.xlabel('Pressure (bar)')
plt.ylabel('Loading Absolute Average (mol/kg)')

# Add legend
plt.legend()

# Display plot
plt.grid(True)
plt.show()
